# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4e23db2f-f5c1-4403-9588-40a0ecdb9bb0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e23db2f-f5c1-4403-9588-40a0ecdb9bb0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("sentiment_data_1000.csv")

# %%
data.head()
# Out:
#                             text sentiment
# 0         The service was awful.  negative
# 1    The service was disgusting.  negative
# 2  This restaurant is excellent!  positive
# 3  This restaurant is fantastic!  positive
# 4  This restaurant is wonderful!  positive

# %%
X_train, X_test, y_train, y_test = train_test_split(data['text'], data['sentiment'], test_size=0.2, random_state=42)

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=10000)
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# %%
model = LogisticRegression()
model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test_tfidf)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
text_to_analyze = ["This restaurant is amazing! The food was delicious."]
text_to_analyze_tfidf = tfidf_vectorizer.transform(text_to_analyze)
predicted_sentiment = model.predict(text_to_analyze_tfidf)

# %%
print("Predicted sentiment:", predicted_sentiment)
# Out:
# Predicted sentiment: ['positive']
